# %%
drug_schema = "abfss://rawdata@drugstorageacc.dfs.core.windows.net/drug_schemas"

# %%
df_rs = spark.readStream.format("cloudFiles") \
    .option("cloudFiles.format", "csv") \
    .schema(drug_schema) \
    .load("abfss://rawdata@drugstorageacc.dfs.core.windows.net/")

# %%
display(df_rs)
